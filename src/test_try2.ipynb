# %%
import pandas as pd
import numpy as np
import os
import torch
from torch.utils.data import Dataset
from utils import *

# %%
file_paths = []
train_dir = 'F:/git_repo/WKN_SSO/new_data/Train/'
test_dir = 'F:/git_repo/WKN_SSO/new_data/Test/'

def load_batdata(root_dir):
    for filename in os.listdir(root_dir):
        file_path = os.path.join(root_dir, filename)
        if file_path.endswith('.csv'):
            file_path = os.path.normpath(file_path)
            file_paths.append(file_path)
    
    for file_path in file_paths:
        file_num = int(file_path.split('\\')[-1].split('_')[-1].split('.')[0])/5
        data = pd.read_csv(file_path)
        inputs = data['amplitude'].values.astype(float)
        inputs = min_max_scale(inputs).reshape(1, -1)
        inputs = torch.from_numpy(inputs.astype(np.float32)).cuda()
    
    return inputs

train_data = load_batdata(train_dir)
print(train_data.shape)
# Out:
# F:\git_repo\WKN_SSO\new_data\Train\time_0.csv 0.0
# F:\git_repo\WKN_SSO\new_data\Train\time_10.csv 2.0
# F:\git_repo\WKN_SSO\new_data\Train\time_100.csv 20.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1000.csv 200.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1005.csv 201.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1010.csv 202.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1015.csv 203.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1020.csv 204.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1025.csv 205.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1030.csv 206.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1035.csv 207.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1040.csv 208.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1045.csv 209.0
# F:\git_repo\WKN_SSO\new_data\Train\time_105.csv 21.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1050.csv 210.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1055.csv 211.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1060.csv 212.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1065.csv 213.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1070.csv 214.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1075.csv 215.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1080.csv 216.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1085.csv 217.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1090.csv 218.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1095.csv 219.0
# F:\git_repo\WKN_SSO\new_data\Train\time_110.csv 22.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1100.csv 220.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1105.csv 221.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1110.csv 222.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1115.csv 223.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1120.csv 224.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1125.csv 225.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1130.csv 226.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1135.csv 227.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1140.csv 228.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1145.csv 229.0
# F:\git_repo\WKN_SSO\new_data\Train\time_115.csv 23.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1150.csv 230.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1155.csv 231.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1160.csv 232.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1165.csv 233.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1170.csv 234.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1175.csv 235.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1180.csv 236.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1185.csv 237.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1190.csv 238.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1195.csv 239.0
# F:\git_repo\WKN_SSO\new_data\Train\time_120.csv 24.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1200.csv 240.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1205.csv 241.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1210.csv 242.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1215.csv 243.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1220.csv 244.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1225.csv 245.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1230.csv 246.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1235.csv 247.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1240.csv 248.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1245.csv 249.0
# F:\git_repo\WKN_SSO\new_data\Train\time_125.csv 25.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1250.csv 250.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1255.csv 251.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1260.csv 252.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1265.csv 253.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1270.csv 254.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1275.csv 255.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1280.csv 256.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1285.csv 257.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1290.csv 258.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1295.csv 259.0
# F:\git_repo\WKN_SSO\new_data\Train\time_130.csv 26.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1300.csv 260.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1305.csv 261.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1310.csv 262.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1315.csv 263.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1320.csv 264.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1325.csv 265.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1330.csv 266.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1335.csv 267.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1340.csv 268.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1345.csv 269.0
# F:\git_repo\WKN_SSO\new_data\Train\time_135.csv 27.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1350.csv 270.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1355.csv 271.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1360.csv 272.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1365.csv 273.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1370.csv 274.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1375.csv 275.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1380.csv 276.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1385.csv 277.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1390.csv 278.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1395.csv 279.0
# F:\git_repo\WKN_SSO\new_data\Train\time_140.csv 28.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1400.csv 280.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1405.csv 281.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1410.csv 282.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1415.csv 283.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1420.csv 284.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1425.csv 285.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1430.csv 286.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1435.csv 287.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1440.csv 288.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1445.csv 289.0
# F:\git_repo\WKN_SSO\new_data\Train\time_145.csv 29.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1450.csv 290.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1455.csv 291.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1460.csv 292.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1465.csv 293.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1470.csv 294.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1475.csv 295.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1480.csv 296.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1485.csv 297.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1490.csv 298.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1495.csv 299.0
# F:\git_repo\WKN_SSO\new_data\Train\time_15.csv 3.0
# F:\git_repo\WKN_SSO\new_data\Train\time_150.csv 30.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1500.csv 300.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1505.csv 301.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1510.csv 302.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1515.csv 303.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1520.csv 304.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1525.csv 305.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1530.csv 306.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1535.csv 307.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1540.csv 308.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1545.csv 309.0
# F:\git_repo\WKN_SSO\new_data\Train\time_155.csv 31.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1550.csv 310.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1555.csv 311.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1560.csv 312.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1565.csv 313.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1570.csv 314.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1575.csv 315.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1580.csv 316.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1585.csv 317.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1590.csv 318.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1595.csv 319.0
# F:\git_repo\WKN_SSO\new_data\Train\time_160.csv 32.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1600.csv 320.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1605.csv 321.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1610.csv 322.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1615.csv 323.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1620.csv 324.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1625.csv 325.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1630.csv 326.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1635.csv 327.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1640.csv 328.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1645.csv 329.0
# F:\git_repo\WKN_SSO\new_data\Train\time_165.csv 33.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1650.csv 330.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1655.csv 331.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1660.csv 332.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1665.csv 333.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1670.csv 334.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1675.csv 335.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1680.csv 336.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1685.csv 337.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1690.csv 338.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1695.csv 339.0
# F:\git_repo\WKN_SSO\new_data\Train\time_170.csv 34.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1700.csv 340.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1705.csv 341.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1710.csv 342.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1715.csv 343.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1720.csv 344.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1725.csv 345.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1730.csv 346.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1735.csv 347.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1740.csv 348.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1745.csv 349.0
# F:\git_repo\WKN_SSO\new_data\Train\time_175.csv 35.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1750.csv 350.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1755.csv 351.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1760.csv 352.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1765.csv 353.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1770.csv 354.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1775.csv 355.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1780.csv 356.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1785.csv 357.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1790.csv 358.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1795.csv 359.0
# F:\git_repo\WKN_SSO\new_data\Train\time_180.csv 36.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1800.csv 360.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1805.csv 361.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1810.csv 362.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1815.csv 363.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1820.csv 364.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1825.csv 365.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1830.csv 366.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1835.csv 367.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1840.csv 368.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1845.csv 369.0
# F:\git_repo\WKN_SSO\new_data\Train\time_185.csv 37.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1850.csv 370.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1855.csv 371.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1860.csv 372.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1865.csv 373.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1870.csv 374.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1875.csv 375.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1880.csv 376.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1885.csv 377.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1890.csv 378.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1895.csv 379.0
# F:\git_repo\WKN_SSO\new_data\Train\time_190.csv 38.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1900.csv 380.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1905.csv 381.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1910.csv 382.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1915.csv 383.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1920.csv 384.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1925.csv 385.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1930.csv 386.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1935.csv 387.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1940.csv 388.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1945.csv 389.0
# F:\git_repo\WKN_SSO\new_data\Train\time_195.csv 39.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1950.csv 390.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1955.csv 391.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1960.csv 392.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1965.csv 393.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1970.csv 394.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1975.csv 395.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1980.csv 396.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1985.csv 397.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1990.csv 398.0
# F:\git_repo\WKN_SSO\new_data\Train\time_1995.csv 399.0
# F:\git_repo\WKN_SSO\new_data\Train\time_20.csv 4.0
# F:\git_repo\WKN_SSO\new_data\Train\time_200.csv 40.0
# F:\git_repo\WKN_SSO\new_data\Train\time_2000.csv 400.0
# F:\git_repo\WKN_SSO\new_data\Train\time_205.csv 41.0
# F:\git_repo\WKN_SSO\new_data\Train\time_210.csv 42.0
# F:\git_repo\WKN_SSO\new_data\Train\time_215.csv 43.0
# F:\git_repo\WKN_SSO\new_data\Train\time_220.csv 44.0
# F:\git_repo\WKN_SSO\new_data\Train\time_225.csv 45.0
# F:\git_repo\WKN_SSO\new_data\Train\time_230.csv 46.0
# F:\git_repo\WKN_SSO\new_data\Train\time_235.csv 47.0
# F:\git_repo\WKN_SSO\new_data\Train\time_240.csv 48.0
# F:\git_repo\WKN_SSO\new_data\Train\time_245.csv 49.0
# F:\git_repo\WKN_SSO\new_data\Train\time_25.csv 5.0
# F:\git_repo\WKN_SSO\new_data\Train\time_250.csv 50.0
# F:\git_repo\WKN_SSO\new_data\Train\time_255.csv 51.0
# F:\git_repo\WKN_SSO\new_data\Train\time_260.csv 52.0
# F:\git_repo\WKN_SSO\new_data\Train\time_265.csv 53.0
# F:\git_repo\WKN_SSO\new_data\Train\time_270.csv 54.0
# F:\git_repo\WKN_SSO\new_data\Train\time_275.csv 55.0
# F:\git_repo\WKN_SSO\new_data\Train\time_280.csv 56.0
# F:\git_repo\WKN_SSO\new_data\Train\time_285.csv 57.0
# F:\git_repo\WKN_SSO\new_data\Train\time_290.csv 58.0
# F:\git_repo\WKN_SSO\new_data\Train\time_295.csv 59.0
# F:\git_repo\WKN_SSO\new_data\Train\time_30.csv 6.0
# F:\git_repo\WKN_SSO\new_data\Train\time_300.csv 60.0
# F:\git_repo\WKN_SSO\new_data\Train\time_305.csv 61.0
# F:\git_repo\WKN_SSO\new_data\Train\time_310.csv 62.0
# F:\git_repo\WKN_SSO\new_data\Train\time_315.csv 63.0
# F:\git_repo\WKN_SSO\new_data\Train\time_320.csv 64.0
# F:\git_repo\WKN_SSO\new_data\Train\time_325.csv 65.0
# F:\git_repo\WKN_SSO\new_data\Train\time_330.csv 66.0
# F:\git_repo\WKN_SSO\new_data\Train\time_335.csv 67.0
# F:\git_repo\WKN_SSO\new_data\Train\time_340.csv 68.0
# F:\git_repo\WKN_SSO\new_data\Train\time_345.csv 69.0
# F:\git_repo\WKN_SSO\new_data\Train\time_35.csv 7.0
# F:\git_repo\WKN_SSO\new_data\Train\time_350.csv 70.0
# F:\git_repo\WKN_SSO\new_data\Train\time_355.csv 71.0
# F:\git_repo\WKN_SSO\new_data\Train\time_360.csv 72.0
# F:\git_repo\WKN_SSO\new_data\Train\time_365.csv 73.0
# F:\git_repo\WKN_SSO\new_data\Train\time_370.csv 74.0
# F:\git_repo\WKN_SSO\new_data\Train\time_375.csv 75.0
# F:\git_repo\WKN_SSO\new_data\Train\time_380.csv 76.0
# F:\git_repo\WKN_SSO\new_data\Train\time_385.csv 77.0
# F:\git_repo\WKN_SSO\new_data\Train\time_390.csv 78.0
# F:\git_repo\WKN_SSO\new_data\Train\time_395.csv 79.0
# F:\git_repo\WKN_SSO\new_data\Train\time_40.csv 8.0
# F:\git_repo\WKN_SSO\new_data\Train\time_400.csv 80.0
# F:\git_repo\WKN_SSO\new_data\Train\time_405.csv 81.0
# F:\git_repo\WKN_SSO\new_data\Train\time_410.csv 82.0
# F:\git_repo\WKN_SSO\new_data\Train\time_415.csv 83.0
# F:\git_repo\WKN_SSO\new_data\Train\time_420.csv 84.0
# F:\git_repo\WKN_SSO\new_data\Train\time_425.csv 85.0
# F:\git_repo\WKN_SSO\new_data\Train\time_430.csv 86.0
# F:\git_repo\WKN_SSO\new_data\Train\time_435.csv 87.0
# F:\git_repo\WKN_SSO\new_data\Train\time_440.csv 88.0
# F:\git_repo\WKN_SSO\new_data\Train\time_445.csv 89.0
# F:\git_repo\WKN_SSO\new_data\Train\time_45.csv 9.0
# F:\git_repo\WKN_SSO\new_data\Train\time_450.csv 90.0
# F:\git_repo\WKN_SSO\new_data\Train\time_455.csv 91.0
# F:\git_repo\WKN_SSO\new_data\Train\time_460.csv 92.0
# F:\git_repo\WKN_SSO\new_data\Train\time_465.csv 93.0
# F:\git_repo\WKN_SSO\new_data\Train\time_470.csv 94.0
# F:\git_repo\WKN_SSO\new_data\Train\time_475.csv 95.0
# F:\git_repo\WKN_SSO\new_data\Train\time_480.csv 96.0
# F:\git_repo\WKN_SSO\new_data\Train\time_485.csv 97.0
# F:\git_repo\WKN_SSO\new_data\Train\time_490.csv 98.0
# F:\git_repo\WKN_SSO\new_data\Train\time_495.csv 99.0
# F:\git_repo\WKN_SSO\new_data\Train\time_5.csv 1.0
# F:\git_repo\WKN_SSO\new_data\Train\time_50.csv 10.0
# F:\git_repo\WKN_SSO\new_data\Train\time_500.csv 100.0
# F:\git_repo\WKN_SSO\new_data\Train\time_505.csv 101.0
# F:\git_repo\WKN_SSO\new_data\Train\time_510.csv 102.0
# F:\git_repo\WKN_SSO\new_data\Train\time_515.csv 103.0
# F:\git_repo\WKN_SSO\new_data\Train\time_520.csv 104.0
# F:\git_repo\WKN_SSO\new_data\Train\time_525.csv 105.0
# F:\git_repo\WKN_SSO\new_data\Train\time_530.csv 106.0
# F:\git_repo\WKN_SSO\new_data\Train\time_535.csv 107.0
# F:\git_repo\WKN_SSO\new_data\Train\time_540.csv 108.0
# F:\git_repo\WKN_SSO\new_data\Train\time_545.csv 109.0
# F:\git_repo\WKN_SSO\new_data\Train\time_55.csv 11.0
# F:\git_repo\WKN_SSO\new_data\Train\time_550.csv 110.0
# F:\git_repo\WKN_SSO\new_data\Train\time_555.csv 111.0
# F:\git_repo\WKN_SSO\new_data\Train\time_560.csv 112.0
# F:\git_repo\WKN_SSO\new_data\Train\time_565.csv 113.0
# F:\git_repo\WKN_SSO\new_data\Train\time_570.csv 114.0
# F:\git_repo\WKN_SSO\new_data\Train\time_575.csv 115.0
# F:\git_repo\WKN_SSO\new_data\Train\time_580.csv 116.0
# F:\git_repo\WKN_SSO\new_data\Train\time_585.csv 117.0
# F:\git_repo\WKN_SSO\new_data\Train\time_590.csv 118.0
# F:\git_repo\WKN_SSO\new_data\Train\time_595.csv 119.0
# F:\git_repo\WKN_SSO\new_data\Train\time_60.csv 12.0
# F:\git_repo\WKN_SSO\new_data\Train\time_600.csv 120.0
# F:\git_repo\WKN_SSO\new_data\Train\time_605.csv 121.0
# F:\git_repo\WKN_SSO\new_data\Train\time_610.csv 122.0
# F:\git_repo\WKN_SSO\new_data\Train\time_615.csv 123.0
# F:\git_repo\WKN_SSO\new_data\Train\time_620.csv 124.0
# F:\git_repo\WKN_SSO\new_data\Train\time_625.csv 125.0
# F:\git_repo\WKN_SSO\new_data\Train\time_630.csv 126.0
# F:\git_repo\WKN_SSO\new_data\Train\time_635.csv 127.0
# F:\git_repo\WKN_SSO\new_data\Train\time_640.csv 128.0
# F:\git_repo\WKN_SSO\new_data\Train\time_645.csv 129.0
# F:\git_repo\WKN_SSO\new_data\Train\time_65.csv 13.0
# F:\git_repo\WKN_SSO\new_data\Train\time_650.csv 130.0
# F:\git_repo\WKN_SSO\new_data\Train\time_655.csv 131.0
# F:\git_repo\WKN_SSO\new_data\Train\time_660.csv 132.0
# F:\git_repo\WKN_SSO\new_data\Train\time_665.csv 133.0
# F:\git_repo\WKN_SSO\new_data\Train\time_670.csv 134.0
# F:\git_repo\WKN_SSO\new_data\Train\time_675.csv 135.0
# F:\git_repo\WKN_SSO\new_data\Train\time_680.csv 136.0
# F:\git_repo\WKN_SSO\new_data\Train\time_685.csv 137.0
# F:\git_repo\WKN_SSO\new_data\Train\time_690.csv 138.0
# F:\git_repo\WKN_SSO\new_data\Train\time_695.csv 139.0
# F:\git_repo\WKN_SSO\new_data\Train\time_70.csv 14.0
# F:\git_repo\WKN_SSO\new_data\Train\time_700.csv 140.0
# F:\git_repo\WKN_SSO\new_data\Train\time_705.csv 141.0
# F:\git_repo\WKN_SSO\new_data\Train\time_710.csv 142.0
# F:\git_repo\WKN_SSO\new_data\Train\time_715.csv 143.0
# F:\git_repo\WKN_SSO\new_data\Train\time_720.csv 144.0
# F:\git_repo\WKN_SSO\new_data\Train\time_725.csv 145.0
# F:\git_repo\WKN_SSO\new_data\Train\time_730.csv 146.0
# F:\git_repo\WKN_SSO\new_data\Train\time_735.csv 147.0
# F:\git_repo\WKN_SSO\new_data\Train\time_740.csv 148.0
# F:\git_repo\WKN_SSO\new_data\Train\time_745.csv 149.0
# F:\git_repo\WKN_SSO\new_data\Train\time_75.csv 15.0
# F:\git_repo\WKN_SSO\new_data\Train\time_750.csv 150.0
# F:\git_repo\WKN_SSO\new_data\Train\time_755.csv 151.0
# F:\git_repo\WKN_SSO\new_data\Train\time_760.csv 152.0
# F:\git_repo\WKN_SSO\new_data\Train\time_765.csv 153.0
# F:\git_repo\WKN_SSO\new_data\Train\time_770.csv 154.0
# F:\git_repo\WKN_SSO\new_data\Train\time_775.csv 155.0
# F:\git_repo\WKN_SSO\new_data\Train\time_780.csv 156.0
# F:\git_repo\WKN_SSO\new_data\Train\time_785.csv 157.0
# F:\git_repo\WKN_SSO\new_data\Train\time_790.csv 158.0
# F:\git_repo\WKN_SSO\new_data\Train\time_795.csv 159.0
# F:\git_repo\WKN_SSO\new_data\Train\time_80.csv 16.0
# F:\git_repo\WKN_SSO\new_data\Train\time_800.csv 160.0
# F:\git_repo\WKN_SSO\new_data\Train\time_805.csv 161.0
# F:\git_repo\WKN_SSO\new_data\Train\time_810.csv 162.0
# F:\git_repo\WKN_SSO\new_data\Train\time_815.csv 163.0
# F:\git_repo\WKN_SSO\new_data\Train\time_820.csv 164.0
# F:\git_repo\WKN_SSO\new_data\Train\time_825.csv 165.0
# F:\git_repo\WKN_SSO\new_data\Train\time_830.csv 166.0
# F:\git_repo\WKN_SSO\new_data\Train\time_835.csv 167.0
# F:\git_repo\WKN_SSO\new_data\Train\time_840.csv 168.0
# F:\git_repo\WKN_SSO\new_data\Train\time_845.csv 169.0
# F:\git_repo\WKN_SSO\new_data\Train\time_85.csv 17.0
# F:\git_repo\WKN_SSO\new_data\Train\time_850.csv 170.0
# F:\git_repo\WKN_SSO\new_data\Train\time_855.csv 171.0
# F:\git_repo\WKN_SSO\new_data\Train\time_860.csv 172.0
# F:\git_repo\WKN_SSO\new_data\Train\time_865.csv 173.0
# F:\git_repo\WKN_SSO\new_data\Train\time_870.csv 174.0
# F:\git_repo\WKN_SSO\new_data\Train\time_875.csv 175.0
# F:\git_repo\WKN_SSO\new_data\Train\time_880.csv 176.0
# F:\git_repo\WKN_SSO\new_data\Train\time_885.csv 177.0
# F:\git_repo\WKN_SSO\new_data\Train\time_890.csv 178.0
# F:\git_repo\WKN_SSO\new_data\Train\time_895.csv 179.0
# F:\git_repo\WKN_SSO\new_data\Train\time_90.csv 18.0
# F:\git_repo\WKN_SSO\new_data\Train\time_900.csv 180.0
# F:\git_repo\WKN_SSO\new_data\Train\time_905.csv 181.0
# F:\git_repo\WKN_SSO\new_data\Train\time_910.csv 182.0
# F:\git_repo\WKN_SSO\new_data\Train\time_915.csv 183.0
# F:\git_repo\WKN_SSO\new_data\Train\time_920.csv 184.0
# F:\git_repo\WKN_SSO\new_data\Train\time_925.csv 185.0
# F:\git_repo\WKN_SSO\new_data\Train\time_930.csv 186.0
# F:\git_repo\WKN_SSO\new_data\Train\time_935.csv 187.0
# F:\git_repo\WKN_SSO\new_data\Train\time_940.csv 188.0
# F:\git_repo\WKN_SSO\new_data\Train\time_945.csv 189.0
# F:\git_repo\WKN_SSO\new_data\Train\time_95.csv 19.0
# F:\git_repo\WKN_SSO\new_data\Train\time_950.csv 190.0
# F:\git_repo\WKN_SSO\new_data\Train\time_955.csv 191.0
# F:\git_repo\WKN_SSO\new_data\Train\time_960.csv 192.0
# F:\git_repo\WKN_SSO\new_data\Train\time_965.csv 193.0
# F:\git_repo\WKN_SSO\new_data\Train\time_970.csv 194.0
# F:\git_repo\WKN_SSO\new_data\Train\time_975.csv 195.0
# F:\git_repo\WKN_SSO\new_data\Train\time_980.csv 196.0
# F:\git_repo\WKN_SSO\new_data\Train\time_985.csv 197.0
# F:\git_repo\WKN_SSO\new_data\Train\time_990.csv 198.0
# F:\git_repo\WKN_SSO\new_data\Train\time_995.csv 199.0
# torch.Size([1, 2560])

# %%
def folder_total(root_dir):
    folder_total = 0
    for filename in os.listdir(root_dir):
        if filename.endswith('.csv'):
            folder_total += 1

    return int(folder_total)

def get_hi(root_dir, file_path, hi_type=1, two_stage_hp=[0.6, 0.6]):
    folder_tot = folder_total(root_dir)
    file_num = int(int(file_path.split('\\')[-1].split('_')[-1].split('.')[0])/5)
    print(file_num)

    if hi_type == 1:
        hi = np.linspace(1,0,folder_tot)
    elif hi_type == 2:
        hi = two_stage_hi(two_stage_hp[0],two_stage_hp[1], folder_tot)

    return hi[file_num]

# %%
class BatteryDataSet(Dataset):
    def __init__(self, root_dir, transform=None, mode='train', label_style=2, two_stage_hp=[0.6, 0.6]):
        self.root_dir = root_dir
        self.transform = transform
        self.mode = mode
        self.label_style = label_style
        self.two_stage_hp = two_stage_hp
        self.file_paths = self.load_batdata()

        def load_batdata(self):
            file_paths = []
            for filename in os.listdir(self.root_dir):
                file_path = os.path.join(self.root_dir, filename)
                if file_path.endswith('.csv'):
                    file_path = os.path.normpath(file_path)
                    file_paths.append(file_path)
            
            return file_paths
    
        def __getitem__(self, index):
            file_path = self.file_paths[index]
            data = pd.read_csv(file_path)
            inputs = data['amplitude'].values.astype(float)
            inputs = min_max_scale(inputs).reshape(1, -1)
            inputs = torch.from_numpy(inputs.astype(np.float32))

            if self.mode == 'train':
                label = get_hi(self.root_dir, file_path, self.label_style, self.two_stage_hp)
                label = torch.tensor(label, dtype=torch.float32)
                if self.transform:
                    inputs = self.transform(inputs)
                
                return inputs, label    
            
            elif self.mode == 'test':
                if self.transform:
                    inputs = self.transform(inputs)
                
                return inputs
            
        def __len__(self):
            return len(self.file_paths)
        
train_dir = 'F:/git_repo/WKN_SSO/new_data/Train/'
test_dir = 'F:/git_repo/WKN_SSO/new_data/Test/'

train_dataset = BatteryDataSet(train_dir)
